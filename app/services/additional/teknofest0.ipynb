# %%
contents= """
مسابقة المواصلات الذّكيّة - Akıllı Ulaşım Yarışması - Smart Transportation Competition
مسابقة ابتكار التكنولوجيا الحيوية - Biyoteknoloji İnovasyon Yarışması - Biotechnology Innovation Competition
مسابقة البلوكتشين - Blokzincir Yarışması - Blockchain Competition
مسابقة تقنيّات البيئة والطّاقة - Çevre ve Enerji Teknolojileri Yarışması - Environment and Energy Technologies Competition
مسابقة تصميم الشرائح الإلكترونية - Çip Tasarım Yarışması - Chip Design Competition
مسابقة الصاروخ ذو الهبوط العمودي - Dikey İnişli Roket Yarışması - Vertical Landing Rocket Competition
مسابقة تقنيات التّعليم - Eğitim Teknolojileri Yarışması - Educational Technologies Competition
مسابقة تقنيات المعيشة الخالية من العوائق - Engelsiz Yaşam Teknolojileri Yarışması - Barrıer-Free Lıvıng Technologıes
مسابقة التكنولوجيا المالية - Finansal Teknolojiler Yarışması - Financial Technologies Competition
مسابقة الأمن السيبراني - HACKMASTERS - HACKMASTERS
مسابقة أنظمة الدفاع الجوي - Hava Savunma Sistemleri Yarışması - Air Defense Systems Competition
مسابقة تصميم الهيلوكبتر - Helikopter Tasarım Yarışması - Helicopter Design Competition
مسابقة تطوير الهايبرلوب - Hyperloop Geliştirme Yarışması - Hyperloop Development Competition
مسابقة التكنولوجيا لصالح البشرية - İnsanlık Yararına Teknoloji Yarışması - Technology For Humanity Competition
مسابقة المركبات البحرية غير المأهولة - İnsansız Deniz Aracı Yarışması - Unmanned Surface Vehicle Competition
مسابقة أنظمة الغواصات بدون إنسان - İnsansız Su Altı Sistemleri Yarışması - Unmanned Underwater Systems Competition
مسابقة تصميم محرك نفّاث - Jet Motor Tasarım Yarışması - Jet Engine Design Competition
مسابقة الاتصالات اللاسلكية - Kablosuz Haberleşme Yarışması - Wireless Communication Competition
مسابقة الحوسبة الكموميّة - Kuantum Hackathon  Yarışması - Quantum Hackathon Competition
مسابقة نموذج الأقمار الصناعية - Model Uydu Yarışması - Model Satellite Competition
مسابقة تشخيص وعلاج الأورام - Onkolojide 3T Yarışması - 3T in Oncology Competition
مسابقة تصحيح الأخطاء والاقتراحات في نظام التّشغيل pardus - Pardus Hata Yakalama ve Öneri Yarışması - Pardus 21 Debugging and Suggestion Competition
مسابقة التطبيقات التكنولوجية في علم النفس - Psikolojide Teknolojik Uygulamalar Yarışması - Technological Applications in Psychology Competition
مسابقة تصميم تقنيات الطاقة النووية - Nükleer Enerji Teknolojileri Tasarım Yarışması - Nuclear Energy Technologies Design Competition
مسابقة العربة ذاتية القيادة - Robotaksi-Binek Otonom Araç Yarışması - Robotaxi-Full Scale Autonomous Vehicle Competition
مسابقة الصواريخ - Roket Yarışması - Rocket Competition
مسابقة الذكاء الاصطناعي في الصحة - Sağlıkta Yapay Zeka Yarışması - Artificial Intelligence in Health Competition
مسابقة التكنولوجيات الرقمية في الصناعة - Sanayide Dijital Teknolojiler Yarışması - Digital Technologies in Industry Competition
مسابقة المسيرات المقاتلة - Savaşan İHA Yarışması - Fighter UAV Competition
مسابقة قطيع الدرونات - Sürü İHA Yarışması - Swarm UAV Competition
مسابقة التقنيات الزراعية - Tarım Teknolojileri Yarışması - Agricultural Technologies Competition
مسابقة دوري الدرونات من تكنوفست - TEKNOFEST Drone Şampiyonası - TEKNOFEST Drone Championship
مسابقة دوري الروبوتات من تكنوفست - TEKNOFEST Robolig Yarışması - TEKNOFEST Roboleague Competition
مسابقة تقنيّات السّفر - TravelX Ideathon - Travel Hackathon
مسابقة الدكتوراه وجائزة tuba - TÜBA-TEKNOFEST Doktora Bilim Ödülleri - TÜBA-TEKNOFEST Doctorate Science Awards
مسابقة معالجة اللغة الطبيعية التركية - Türkçe Doğal Dil İşleme Yarışması - Turkish Natural Language Processing Competition
مسابقة الذكاء الاصطناعي في نموذج اللغة T3 - T3 AI Hackathon - T3 AI Hackathon
مسابقة الذكاء الاصطناعي في الطيران - Havacılıkta Yapay Zeka Yarışması - Artificial Intelligence in Transportation Competition
مسابقة السيارات الكهربائية الدولية - Uluslararası Efficiency Challenge Elektrikli Araç Yarışları - International Efficiency Challenge Electric Vehicle Races
مسابقات مشاريع بحثية لطلبة الجامعات - Üniversite Öğrencileri Araştırma Proje Yarışmaları - University Students Research Projects Competitions
كأس العالم للطائرات بدون طيار - World Drone Cup - World Drone Cup
الطائرة بدون طيار (المسابقة الدولية) - Uluslararası İnsansız Hava Aracı Yarışması - International Unmanned Aerial Vehicle Competition
مسابقة تكنوفست للتصميم المعماري والبصري - TEKNOFEST Mimari ve Görsel Tasarım Yarışması - TEKNOFEST Architectural and Visual Design Competition
مسابقة المركبات الأرضية غير المأهولة - İnsansız Kara Aracı Yarışması - Unmanned Ground Vehicle
هاكاثون التجارة الإلكترونية - E-Ticaret Hackathonu - E-Commerce Hackathon
مسابقة تحديد المواقع بتقنية الجيل الخامس - 5G Konumlandırma Yarışması - 5G Positioning Competition
مسابقة الصواريخ تحت الماء - Su Altı Roket Yarışması - Underwater Rocket Competition
"""

# %%
print("=TEXTJOIN(", ", TRUE, ")
for line in contents.split("\n"):
    print(f'IF(REGEXMATCH(\'form\'!M3, "{line}"), "{line}", "")')
print(")")
# Out:
# =TEXTJOIN( , TRUE,
# IF(REGEXMATCH('form'!M3, ""), "", "")
# IF(REGEXMATCH('form'!M3, "مسابقة المواصلات الذّكيّة - Akıllı Ulaşım Yarışması - Smart Transportation Competition"), "مسابقة المواصلات الذّكيّة - Akıllı Ulaşım Yarışması - Smart Transportation Competition", "")
# IF(REGEXMATCH('form'!M3, "مسابقة ابتكار التكنولوجيا الحيوية - Biyoteknoloji İnovasyon Yarışması - Biotechnology Innovation Competition"), "مسابقة ابتكار التكنولوجيا الحيوية - Biyoteknoloji İnovasyon Yarışması - Biotechnology Innovation Competition", "")
# IF(REGEXMATCH('form'!M3, "مسابقة البلوكتشين - Blokzincir Yarışması - Blockchain Competition"), "مسابقة البلوكتشين - Blokzincir Yarışması - Blockchain Competition", "")
# IF(REGEXMATCH('form'!M3, "مسابقة تقنيّات البيئة والطّاقة - Çevre ve Enerji Teknolojileri Yarışması - Environment and Energy Technologies Competition"), "مسابقة تقنيّات البيئة والطّاقة - Çevre ve Enerji Teknolojileri Yarışması - Environment and Energy Technologies Competition", "")
# ...

# %%
print('=TEXTJOIN(", ", TRUE, ', end='')
print(", ".join(f'IF(REGEXMATCH(\'form\'!M3, "{line}"), "{line}", "")' for line in contents.split("\n")), end='')
print(')')
# Out:
# =TEXTJOIN(", ", TRUE, IF(REGEXMATCH('form'!M3, ""), "", ""), IF(REGEXMATCH('form'!M3, "مسابقة المواصلات الذّكيّة - Akıllı Ulaşım Yarışması - Smart Transportation Competition"), "مسابقة المواصلات الذّكيّة - Akıllı Ulaşım Yarışması - Smart Transportation Competition", ""), IF(REGEXMATCH('form'!M3, "مسابقة ابتكار التكنولوجيا الحيوية - Biyoteknoloji İnovasyon Yarışması - Biotechnology Innovation Competition"), "مسابقة ابتكار التكنولوجيا الحيوية - Biyoteknoloji İnovasyon Yarışması - Biotechnology Innovation Competition", ""), IF(REGEXMATCH('form'!M3, "مسابقة البلوكتشين - Blokzincir Yarışması - Blockchain Competition"), "مسابقة البلوكتشين - Blokzincir Yarışması - Blockchain Competition", ""), IF(REGEXMATCH('form'!M3, "مسابقة تقنيّات البيئة والطّاقة - Çevre ve Enerji Teknolojileri Yarışması - Environment and Energy Technologies Competition"), "مسابقة تقنيّات البيئة والطّاقة - Çevre ve Enerji Teknolojileri Yarışması - Environment and Energy Technologies Competition", ""), IF(REGEXMATCH('form
# ...

# %%
print('=TEXTJOIN(", ", TRUE, ', end='')
for line in contents.split("\n"):
    if line:
        print(f'IF(REGEXMATCH(\'form\'!M3, "{line}"), "{line}", ""), ', end='')
print(')')
# Out:
# =TEXTJOIN(", ", TRUE, IF(REGEXMATCH('form'!M3, "مسابقة المواصلات الذّكيّة - Akıllı Ulaşım Yarışması - Smart Transportation Competition"), "مسابقة المواصلات الذّكيّة - Akıllı Ulaşım Yarışması - Smart Transportation Competition", ""), IF(REGEXMATCH('form'!M3, "مسابقة ابتكار التكنولوجيا الحيوية - Biyoteknoloji İnovasyon Yarışması - Biotechnology Innovation Competition"), "مسابقة ابتكار التكنولوجيا الحيوية - Biyoteknoloji İnovasyon Yarışması - Biotechnology Innovation Competition", ""), IF(REGEXMATCH('form'!M3, "مسابقة البلوكتشين - Blokzincir Yarışması - Blockchain Competition"), "مسابقة البلوكتشين - Blokzincir Yarışması - Blockchain Competition", ""), IF(REGEXMATCH('form'!M3, "مسابقة تقنيّات البيئة والطّاقة - Çevre ve Enerji Teknolojileri Yarışması - Environment and Energy Technologies Competition"), "مسابقة تقنيّات البيئة والطّاقة - Çevre ve Enerji Teknolojileri Yarışması - Environment and Energy Technologies Competition", ""), IF(REGEXMATCH('form'!M3, "مسابقة تصميم الشرائح الإلكترونية
# ...

# %%
ar_contents = """
مسابقة المواصلات الذّكيّة
مسابقة ابتكار التكنولوجيا الحيوية
مسابقة البلوكتشين
مسابقة تقنيّات البيئة والطّاقة
مسابقة تصميم الشرائح الإلكترونية
مسابقة الصاروخ ذو الهبوط العمودي
مسابقة تقنيات التّعليم
مسابقة تقنيات المعيشة الخالية من العوائق
مسابقة التكنولوجيا المالية
مسابقة الأمن السيبراني
مسابقة أنظمة الدفاع الجوي
مسابقة تصميم الهيلوكبتر
مسابقة تطوير الهايبرلوب
مسابقة التكنولوجيا لصالح البشرية
مسابقة المركبات البحرية غير المأهولة
مسابقة أنظمة الغواصات بدون إنسان
مسابقة تصميم محرك نفّاث
مسابقة الاتصالات اللاسلكية
مسابقة الحوسبة الكموميّة
مسابقة نموذج الأقمار الصناعية
مسابقة تشخيص وعلاج الأورام
مسابقة تصحيح الأخطاء والاقتراحات في نظام التّشغيل pardus
مسابقة التطبيقات التكنولوجية في علم النفس
مسابقة تصميم تقنيات الطاقة النووية
مسابقة العربة ذاتية القيادة
مسابقة الصواريخ
مسابقة الذكاء الاصطناعي في الصحة
مسابقة التكنولوجيات الرقمية في الصناعة
مسابقة المسيرات المقاتلة
مسابقة قطيع الدرونات
مسابقة التقنيات الزراعية
مسابقة دوري الدرونات من تكنوفست
مسابقة دوري الروبوتات من تكنوفست
مسابقة تقنيّات السّفر
مسابقة الدكتوراه وجائزة tuba
مسابقة معالجة اللغة الطبيعية التركية
مسابقة الذكاء الاصطناعي في نموذج اللغة T3
مسابقة الذكاء الاصطناعي في الطيران
مسابقة السيارات الكهربائية الدولية
مسابقات مشاريع بحثية لطلبة الجامعات
كأس العالم للطائرات بدون طيار
الطائرة بدون طيار (المسابقة الدولية)
مسابقة تكنوفست للتصميم المعماري والبصري
مسابقة المركبات الأرضية غير المأهولة
هاكاثون التجارة الإلكترونية
مسابقة تحديد المواقع بتقنية الجيل الخامس
مسابقة الصواريخ تحت الماء
"""

# %%
print('=TEXTJOIN(", ", TRUE, ', end='')
count = 0
for line, line_ar in zip(contents.split("\n"), ar_contents.split("\n")):
    if line:
        if count != 0:
            print(", ", end='')
        print(f'IF(REGEXMATCH(\'form\'!M3, "{line}"), "{line_ar}", "")', end='')
        count += 1
print(')')
# Out:
# =TEXTJOIN(", ", TRUE, IF(REGEXMATCH('form'!M3, "مسابقة المواصلات الذّكيّة - Akıllı Ulaşım Yarışması - Smart Transportation Competition"), "مسابقة المواصلات الذّكيّة", ""), IF(REGEXMATCH('form'!M3, "مسابقة ابتكار التكنولوجيا الحيوية - Biyoteknoloji İnovasyon Yarışması - Biotechnology Innovation Competition"), "مسابقة ابتكار التكنولوجيا الحيوية", ""), IF(REGEXMATCH('form'!M3, "مسابقة البلوكتشين - Blokzincir Yarışması - Blockchain Competition"), "مسابقة البلوكتشين", ""), IF(REGEXMATCH('form'!M3, "مسابقة تقنيّات البيئة والطّاقة - Çevre ve Enerji Teknolojileri Yarışması - Environment and Energy Technologies Competition"), "مسابقة تقنيّات البيئة والطّاقة", ""), IF(REGEXMATCH('form'!M3, "مسابقة تصميم الشرائح الإلكترونية - Çip Tasarım Yarışması - Chip Design Competition"), "مسابقة تصميم الشرائح الإلكترونية", ""), IF(REGEXMATCH('form'!M3, "مسابقة الصاروخ ذو الهبوط العمودي - Dikey İnişli Roket Yarışması - Vertical Landing Rocket Competition"), "مسابقة الصاروخ ذو الهبوط العمودي", ""), IF(REGEXM
# ...

# %%
print('=TEXTJOIN(", ", TRUE, ', end='')
print(", ".join((f'IF(REGEXMATCH(\'form\'!M3, "{line}"), "{line_ar}", "")' for line, line_ar in zip(contents.split("\n"), ar_contents.split("\n")) if line and line_ar)), end='')
print(')')
# Out:
# =TEXTJOIN(", ", TRUE, IF(REGEXMATCH('form'!M3, "مسابقة المواصلات الذّكيّة - Akıllı Ulaşım Yarışması - Smart Transportation Competition"), "مسابقة المواصلات الذّكيّة", ""), IF(REGEXMATCH('form'!M3, "مسابقة ابتكار التكنولوجيا الحيوية - Biyoteknoloji İnovasyon Yarışması - Biotechnology Innovation Competition"), "مسابقة ابتكار التكنولوجيا الحيوية", ""), IF(REGEXMATCH('form'!M3, "مسابقة البلوكتشين - Blokzincir Yarışması - Blockchain Competition"), "مسابقة البلوكتشين", ""), IF(REGEXMATCH('form'!M3, "مسابقة تقنيّات البيئة والطّاقة - Çevre ve Enerji Teknolojileri Yarışması - Environment and Energy Technologies Competition"), "مسابقة تقنيّات البيئة والطّاقة", ""), IF(REGEXMATCH('form'!M3, "مسابقة تصميم الشرائح الإلكترونية - Çip Tasarım Yarışması - Chip Design Competition"), "مسابقة تصميم الشرائح الإلكترونية", ""), IF(REGEXMATCH('form'!M3, "مسابقة الصاروخ ذو الهبوط العمودي - Dikey İnişli Roket Yarışması - Vertical Landing Rocket Competition"), "مسابقة الصاروخ ذو الهبوط العمودي", ""), IF(REGEXM
# ...
